# %% [markdown]
# # Finding the Square Root of an Integer
# Find the square root of the integer without using any Python library. You have to find the floor value of the square root.
#
# For example if the given number is 16, then the answer would be 4.
#
# If the given number is 27, the answer would be 5 because sqrt(5) = 5.196 whose floor value is 5.
#
# The expected time complexity is `O(log(n))`
#
# Here is some boilerplate code and test cases to start with:

# %%
def sqrt(n):
    """
    Calculate the floored square root of a number

    Args:
       number(int): Number to find the floored squared root
    Returns:
       int: Floored Square Root
    """
    initial_guess = n
    updated_guess = (n + 1) // 2
    
    while updated_guess < initial_guess:
        initial_guess = updated_guess
        updated_guess = (initial_guess + n // initial_guess) // 2
        
    return updated_guess

# %%
import math
test_cases = [
    (0, 0),
    (1, 1),
    (9, 3),
    (10, 3),
    (16, 4)
]

for x in range(2, 4):
    test_cases.append((x, math.sqrt(x) // 1))

for test_case in test_cases:
    test_input = test_case[0]
    expected_result = test_case[1]
    actual_result = sqrt(test_input)
    
    if expected_result == actual_result:
        print("Pass")
    else:
        print("Fail")
    print(f"Expected: {expected_result}\nActual:  {actual_result}\n\n")
# Out:
# Pass
# Expected: 0
# Actual:  0
#
#
# Pass
# Expected: 1
# Actual:  1
#
#
# Pass
# Expected: 3
# Actual:  3
#
#
# Pass
# Expected: 3
# Actual:  3
#
#
# Pass
# Expected: 4
# Actual:  4
#
#
# Pass
# Expected: 1.0
# Actual:  1
#
#
# Pass
# Expected: 1.0
# Actual:  1

# %% [markdown]
# ## Exploration

# %%
import pandas as pd
import numpy as np

# %%
math.sqrt(3) / 3
# Out:
# 0.5773502691896257

# %%
def sqrt(n):
    """
    Calculate the floored square root of a number

    Args:
       number(int): Number to find the floored squared root
    Returns:
       int: Floored Square Root
    """
    x = n
    y = (x + 1) // 2
    counter = 0
    print("start", "x: ", x, "y: ", y)
    
    while y < x:
        counter += 1
        print("iteration: ", counter)
        x = y
        z =  n // x

        print("n floor division y: ", z)
        print("then add to  y: ", z + y)
        print("...then floor division with 2: ", (z + y) // 2)
        y = (x + n // x) // 2
        print("x: ", x, "y: ", y)
        
    return x, counter

# %% [markdown]
# ## Writeup
#
# Time complexity is `O(log(n))`. Space complexity is `O(1)`.
# I used the "Babylonian method" for approximating square roots (one of the oldest known algorithms). We start with an initial guess, and then update that guess until the answers converge to a desired level of precision. Because we are returning only the integer answer, the algorithm has converged when the guess and the updated guess are identical.
#
# Per [Wikipedia](https://en.wikipedia.org/wiki/Methods_of_computing_square_roots):
# >The basic idea is that if `x` is an overestimate to the square root of a non-negative real number S then
# `S / x` will be an underestimate, or vice versa, and so the average of these two numbers may reasonably be expected to provide a better approximation.
#
# **Pseudocode**
# ```
# 1. Make an initial guess -- here we use the input (`n`), add 1, and (floor) divide by 2
# 2. Update that guess by:
#   a. (floor) dividing the input by the previous guess
#   b. then adding the result to the previous guess,
#   c. then (floor) dividing the result by 2.
# 3. when initial guess and updated guess are the same, return the guess
# ```
#
# As mentioned above, we need to start with an initial (seed) value that is greater than the actual square root--but ideally not by much. I could have devised the seed value in a number of clever ways, but I went for something simple. We know that only in two cases is the actual squre root of an integer larger than that integer divided by two -- the square root of two and the square root of three. In both cases, we can add one to ensure that our initial guess is larger than the square root, and this addition will be proportionally smaller as our input grows, which doesn't add significantly to the amount of time required for convergence.
#
# This last part of updating the guess is crucial. We are essentially (but not exactly) halving our guess each time, which produces a `O(log(n))` time complexity.
#
# I tested this myself by building the following results table using the first thirty perfect squares. We can see that although the input is increasing exponentially, the output is increasing basically linearly, and is close to log-base-2 of the input.
#
# | input | output | iterations | log2(input) |
# |-------|--------|------------|-------------|
# | 1     | 1      | 0          | 0.0         |
# | 4     | 2      | 1          | 2.0         |
# | 9     | 3      | 2          | 3.0         |
# | 16    | 4      | 3          | 4.0         |
# | 25    | 5      | 3          | 4.0         |
# | 36    | 6      | 3          | 5.0         |
# | 49    | 7      | 4          | 5.0         |
# | 64    | 8      | 4          | 6.0         |
# | 81    | 9      | 4          | 6.0         |
# | 100   | 10     | 4          | 6.0         |
# | 121   | 11     | 5          | 6.0         |
# | 144   | 12     | 5          | 7.0         |
# | 169   | 13     | 5          | 7.0         |
# | 196   | 14     | 5          | 7.0         |
# | 225   | 15     | 5          | 7.0         |
# | 256   | 16     | 5          | 8.0         |
# | 289   | 17     | 5          | 8.0         |
# | 324   | 18     | 5          | 8.0         |
# | 361   | 19     | 6          | 8.0         |
# | 400   | 20     | 6          | 8.0         |
# | 441   | 21     | 6          | 8.0         |
# | 484   | 22     | 6          | 8.0         |
# | 529   | 23     | 6          | 9.0         |
# | 576   | 24     | 6          | 9.0         |
# | 625   | 25     | 6          | 9.0         |
# | 676   | 26     | 6          | 9.0         |
# | 729   | 27     | 6          | 9.0         |
# | 784   | 28     | 6          | 9.0         |
# | 841   | 29     | 6          | 9.0         |
# | 900   | 30     | 6          | 9.0         |

# %%
math.sqrt(5)
# Out:
# 2.23606797749979

# %%
math.sqrt(7)
# Out:
# 2.6457513110645907

# %%
sqrt(100)
# Out:
# 10

# %%
sqrt(3)
# Out:
# start x:  3 y:  2
# iteration:  1
# n floor division y:  1
# then add to  y:  3
# ...then floor division with 2:  1
# x:  2 y:  1
# iteration:  2
# n floor division y:  3
# then add to  y:  4
# ...then floor division with 2:  2
# x:  1 y:  2
# (1, 2)

# %%
(3 + 1) // 2
# Out:
# 2

# %%
perfect_squares = [x**2 for x in range(1, 31)]

# %%
print(perfect_squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900]

# %%
np.version.version
# Out:
# '1.16.2'

# %%
5 ** -2
# Out:
# 0.04

# %%
results_table = []
for input_ in perfect_squares:
    output, iterations = sqrt(input_)
    series = {"input": input_, "output": output, "iterations": iterations}
    results_table.append(series)
# Out:
# start x:  1 y:  1
# start x:  4 y:  2
# iteration:  1
# n floor division y:  2
# then add to  y:  4
# ...then floor division with 2:  2
# x:  2 y:  2
# start x:  9 y:  5
# iteration:  1
# n floor division y:  1
# then add to  y:  6
# ...then floor division with 2:  3
# x:  5 y:  3
# iteration:  2
# n floor division y:  3
# then add to  y:  6
# ...then floor division with 2:  3
# x:  3 y:  3
# start x:  16 y:  8
# iteration:  1
# n floor division y:  2
# then add to  y:  10
# ...then floor division with 2:  5
# x:  8 y:  5
# iteration:  2
# n floor division y:  3
# then add to  y:  8
# ...then floor division with 2:  4
# x:  5 y:  4
# iteration:  3
# n floor division y:  4
# then add to  y:  8
# ...then floor division with 2:  4
# x:  4 y:  4
# start x:  25 y:  13
# iteration:  1
# n floor division y:  1
# then add to  y:  14
# ...then floor division with 2:  7
# x:  13 y:  7
# iteration:  2
# n floor division y:  3
# then add to  y:  10
# ...then floor division with 2:  5
# x:  7 y:  5
# iteration:  3
# n floor division y:  5
# then add to  y:  10
# ...then floor division with 2:  5
# x:  5 y:  5
# start x:  36 y:  18
# iteration:  1
# n floor division y:  2
# then add to  y:  20
# ...then floor division with 2:  10
# x:  18 y:  10
# iteration:  2
# n floor division y:  3
# then add to  y:  13
# ...then floor division with 2:  6
# x:  10 y:  6
# iteration:  3
# n floor division y:  6
# then add to  y:  12
# ...then floor division with 2:  6
# x:  6 y:  6
# start x:  49 y:  25
# iteration:  1
# n floor division y:  1
# then add to  y:  26
# ...then floor division with 2:  13
# x:  25 y:  13
# iteration:  2
# n floor division y:  3
# then add to  y:  16
# ...then floor division with 2:  8
# x:  13 y:  8
# iteration:  3
# n floor division y:  6
# then add to  y:  14
# ...then floor division with 2:  7
# x:  8 y:  7
# iteration:  4
# n floor division y:  7
# then add to  y:  14
# ...then floor division with 2:  7
# x:  7 y:  7
# start x:  64 y:  32
# iteration:  1
# n floor division y:  2
# then add to  y:  34
# ...then floor division with 2:  17
# x:  32 y:  17
# iteration:  2
# n floor division y:  3
# then add to  y:  20
# ...then floor division with 2:  10
# x:  17 y:  10
# iteration:  3
# n floor division y:  6
# then add to  y:  16
# ...then floor division with 2:  8
# x:  10 y:  8
# iteration:  4
# n floor division y:  8
# then add to  y:  16
# ...then floor division with 2:  8
# x:  8 y:  8
# start x:  81 y:  41
# iteration:  1
# n floor division y:  1
# then add to  y:  42
# ...then floor division with 2:  21
# x:  41 y:  21
# iteration:  2
# n floor division y:  3
# then add to  y:  24
# ...then floor division with 2:  12
# x:  21 y:  12
# iteration:  3
# n floor division y:  6
# then add to  y:  18
# ...then floor division with 2:  9
# x:  12 y:  9
# iteration:  4
# n floor division y:  9
# then add to  y:  18
# ...then floor division with 2:  9
# x:  9 y:  9
# start x:  100 y:  50
# iteration:  1
# n floor division y:  2
# then add to  y:  52
# ...then floor division with 2:  26
# x:  50 y:  26
# iteration:  2
# n floor division y:  3
# then add to  y:  29
# ...then floor division with 2:  14
# x:  26 y:  14
# iteration:  3
# n floor division y:  7
# then add to  y:  21
# ...then floor division with 2:  10
# x:  14 y:  10
# iteration:  4
# n floor division y:  10
# then add to  y:  20
# ...then floor division with 2:  10
# x:  10 y:  10
# start x:  121 y:  61
# iteration:  1
# n floor division y:  1
# then add to  y:  62
# ...then floor division with 2:  31
# x:  61 y:  31
# iteration:  2
# n floor division y:  3
# then add to  y:  34
# ...then floor division with 2:  17
# x:  31 y:  17
# iteration:  3
# n floor division y:  7
# then add to  y:  24
# ...then floor division with 2:  12
# x:  17 y:  12
# iteration:  4
# n floor division y:  10
# then add to  y:  22
# ...then floor division with 2:  11
# x:  12 y:  11
# iteration:  5
# n floor division y:  11
# then add to  y:  22
# ...then floor division with 2:  11
# x:  11 y:  11
# start x:  144 y:  72
# iteration:  1
# n floor division y:  2
# then add to  y:  74
# ...then floor division with 2:  37
# x:  72 y:  37
# iteration:  2
# n floor division y:  3
# then add to  y:  40
# ...then floor division with 2:  20
# x:  37 y:  20
# iteration:  3
# n floor division y:  7
# then add to  y:  27
# ...then floor division with 2:  13
# x:  20 y:  13
# iteration:  4
# n floor division y:  11
# then add to  y:  24
# ...then floor division with 2:  12
# x:  13 y:  12
# iteration:  5
# n floor division y:  12
# then add to  y:  24
# ...then floor division with 2:  12
# x:  12 y:  12
# start x:  169 y:  85
# iteration:  1
# n floor division y:  1
# then add to  y:  86
# ...then floor division with 2:  43
# x:  85 y:  43
# iteration:  2
# n floor division y:  3
# then add to  y:  46
# ...then floor division with 2:  23
# x:  43 y:  23
# iteration:  3
# n floor division y:  7
# then add to  y:  30
# ...then floor division with 2:  15
# x:  23 y:  15
# iteration:  4
# n floor division y:  11
# then add to  y:  26
# ...then floor division with 2:  13
# x:  15 y:  13
# iteration:  5
# n floor division y:  13
# then add to  y:  26
# ...then floor division with 2:  13
# x:  13 y:  13
# start x:  196 y:  98
# iteration:  1
# n floor division y:  2
# then add to  y:  100
# ...then floor division with 2:  50
# x:  98 y:  50
# iteration:  2
# n floor division y:  3
# then add to  y:  53
# ...then floor division with 2:  26
# x:  50 y:  26
# iteration:  3
# n floor division y:  7
# then add to  y:  33
# ...then floor division with 2:  16
# x:  26 y:  16
# iteration:  4
# n floor division y:  12
# then add to  y:  28
# ...then floor division with 2:  14
# x:  16 y:  14
# iteration:  5
# n floor division y:  14
# then add to  y:  28
# ...then floor division with 2:  14
# x:  14 y:  14
# start x:  225 y:  113
# iteration:  1
# n floor division y:  1
# then add to  y:  114
# ...then floor division with 2:  57
# x:  113 y:  57
# iteration:  2
# n floor division y:  3
# then add to  y:  60
# ...then floor division with 2:  30
# x:  57 y:  30
# iteration:  3
# n floor division y:  7
# then add to  y:  37
# ...then floor division with 2:  18
# x:  30 y:  18
# iteration:  4
# n floor division y:  12
# then add to  y:  30
# ...then floor division with 2:  15
# x:  18 y:  15
# iteration:  5
# n floor division y:  15
# then add to  y:  30
# ...then floor division with 2:  15
# x:  15 y:  15
# start x:  256 y:  128
# iteration:  1
# n floor division y:  2
# then add to  y:  130
# ...then floor division with 2:  65
# x:  128 y:  65
# iteration:  2
# n floor division y:  3
# then add to  y:  68
# ...then floor division with 2:  34
# x:  65 y:  34
# iteration:  3
# n floor division y:  7
# then add to  y:  41
# ...then floor division with 2:  20
# x:  34 y:  20
# iteration:  4
# n floor division y:  12
# then add to  y:  32
# ...then floor division with 2:  16
# x:  20 y:  16
# iteration:  5
# n floor division y:  16
# then add to  y:  32
# ...then floor division with 2:  16
# x:  16 y:  16
# start x:  289 y:  145
# iteration:  1
# n floor division y:  1
# then add to  y:  146
# ...then floor division with 2:  73
# x:  145 y:  73
# iteration:  2
# n floor division y:  3
# then add to  y:  76
# ...then floor division with 2:  38
# x:  73 y:  38
# iteration:  3
# n floor division y:  7
# then add to  y:  45
# ...then floor division with 2:  22
# x:  38 y:  22
# iteration:  4
# n floor division y:  13
# then add to  y:  35
# ...then floor division with 2:  17
# x:  22 y:  17
# iteration:  5
# n floor division y:  17
# then add to  y:  34
# ...then floor division with 2:  17
# x:  17 y:  17
# start x:  324 y:  162
# iteration:  1
# n floor division y:  2
# then add to  y:  164
# ...then floor division with 2:  82
# x:  162 y:  82
# iteration:  2
# n floor division y:  3
# then add to  y:  85
# ...then floor division with 2:  42
# x:  82 y:  42
# iteration:  3
# n floor division y:  7
# then add to  y:  49
# ...then floor division with 2:  24
# x:  42 y:  24
# iteration:  4
# n floor division y:  13
# then add to  y:  37
# ...then floor division with 2:  18
# x:  24 y:  18
# iteration:  5
# n floor division y:  18
# then add to  y:  36
# ...then floor division with 2:  18
# x:  18 y:  18
# start x:  361 y:  181
# iteration:  1
# n floor division y:  1
# then add to  y:  182
# ...then floor division with 2:  91
# x:  181 y:  91
# iteration:  2
# n floor division y:  3
# then add to  y:  94
# ...then floor division with 2:  47
# x:  91 y:  47
# iteration:  3
# n floor division y:  7
# then add to  y:  54
# ...then floor division with 2:  27
# x:  47 y:  27
# iteration:  4
# n floor division y:  13
# then add to  y:  40
# ...then floor division with 2:  20
# x:  27 y:  20
# iteration:  5
# n floor division y:  18
# then add to  y:  38
# ...then floor division with 2:  19
# x:  20 y:  19
# iteration:  6
# n floor division y:  19
# then add to  y:  38
# ...then floor division with 2:  19
# x:  19 y:  19
# start x:  400 y:  200
# iteration:  1
# n floor division y:  2
# then add to  y:  202
# ...then floor division with 2:  101
# x:  200 y:  101
# iteration:  2
# n floor division y:  3
# then add to  y:  104
# ...then floor division with 2:  52
# x:  101 y:  52
# iteration:  3
# n floor division y:  7
# then add to  y:  59
# ...then floor division with 2:  29
# x:  52 y:  29
# iteration:  4
# n floor division y:  13
# then add to  y:  42
# ...then floor division with 2:  21
# x:  29 y:  21
# iteration:  5
# n floor division y:  19
# then add to  y:  40
# ...then floor division with 2:  20
# x:  21 y:  20
# iteration:  6
# n floor division y:  20
# then add to  y:  40
# ...then floor division with 2:  20
# x:  20 y:  20
# start x:  441 y:  221
# iteration:  1
# n floor division y:  1
# then add to  y:  222
# ...then floor division with 2:  111
# x:  221 y:  111
# iteration:  2
# n floor division y:  3
# then add to  y:  114
# ...then floor division with 2:  57
# x:  111 y:  57
# iteration:  3
# n floor division y:  7
# then add to  y:  64
# ...then floor division with 2:  32
# x:  57 y:  32
# iteration:  4
# n floor division y:  13
# then add to  y:  45
# ...then floor division with 2:  22
# x:  32 y:  22
# iteration:  5
# n floor division y:  20
# then add to  y:  42
# ...then floor division with 2:  21
# x:  22 y:  21
# iteration:  6
# n floor division y:  21
# then add to  y:  42
# ...then floor division with 2:  21
# x:  21 y:  21
# start x:  484 y:  242
# iteration:  1
# n floor division y:  2
# then add to  y:  244
# ...then floor division with 2:  122
# x:  242 y:  122
# iteration:  2
# n floor division y:  3
# then add to  y:  125
# ...then floor division with 2:  62
# x:  122 y:  62
# iteration:  3
# n floor division y:  7
# then add to  y:  69
# ...then floor division with 2:  34
# x:  62 y:  34
# iteration:  4
# n floor division y:  14
# then add to  y:  48
# ...then floor division with 2:  24
# x:  34 y:  24
# iteration:  5
# n floor division y:  20
# then add to  y:  44
# ...then floor division with 2:  22
# x:  24 y:  22
# iteration:  6
# n floor division y:  22
# then add to  y:  44
# ...then floor division with 2:  22
# x:  22 y:  22
# start x:  529 y:  265
# iteration:  1
# n floor division y:  1
# then add to  y:  266
# ...then floor division with 2:  133
# x:  265 y:  133
# iteration:  2
# n floor division y:  3
# then add to  y:  136
# ...then floor division with 2:  68
# x:  133 y:  68
# iteration:  3
# n floor division y:  7
# then add to  y:  75
# ...then floor division with 2:  37
# x:  68 y:  37
# iteration:  4
# n floor division y:  14
# then add to  y:  51
# ...then floor division with 2:  25
# x:  37 y:  25
# iteration:  5
# n floor division y:  21
# then add to  y:  46
# ...then floor division with 2:  23
# x:  25 y:  23
# iteration:  6
# n floor division y:  23
# then add to  y:  46
# ...then floor division with 2:  23
# x:  23 y:  23
# start x:  576 y:  288
# iteration:  1
# n floor division y:  2
# then add to  y:  290
# ...then floor division with 2:  145
# x:  288 y:  145
# iteration:  2
# n floor division y:  3
# then add to  y:  148
# ...then floor division with 2:  74
# x:  145 y:  74
# iteration:  3
# n floor division y:  7
# then add to  y:  81
# ...then floor division with 2:  40
# x:  74 y:  40
# iteration:  4
# n floor division y:  14
# then add to  y:  54
# ...then floor division with 2:  27
# x:  40 y:  27
# iteration:  5
# n floor division y:  21
# then add to  y:  48
# ...then floor division with 2:  24
# x:  27 y:  24
# iteration:  6
# n floor division y:  24
# then add to  y:  48
# ...then floor division with 2:  24
# x:  24 y:  24
# start x:  625 y:  313
# iteration:  1
# n floor division y:  1
# then add to  y:  314
# ...then floor division with 2:  157
# x:  313 y:  157
# iteration:  2
# n floor division y:  3
# then add to  y:  160
# ...then floor division with 2:  80
# x:  157 y:  80
# iteration:  3
# n floor division y:  7
# then add to  y:  87
# ...then floor division with 2:  43
# x:  80 y:  43
# iteration:  4
# n floor division y:  14
# then add to  y:  57
# ...then floor division with 2:  28
# x:  43 y:  28
# iteration:  5
# n floor division y:  22
# then add to  y:  50
# ...then floor division with 2:  25
# x:  28 y:  25
# iteration:  6
# n floor division y:  25
# then add to  y:  50
# ...then floor division with 2:  25
# x:  25 y:  25
# start x:  676 y:  338
# iteration:  1
# n floor division y:  2
# then add to  y:  340
# ...then floor division with 2:  170
# x:  338 y:  170
# iteration:  2
# n floor division y:  3
# then add to  y:  173
# ...then floor division with 2:  86
# x:  170 y:  86
# iteration:  3
# n floor division y:  7
# then add to  y:  93
# ...then floor division with 2:  46
# x:  86 y:  46
# iteration:  4
# n floor division y:  14
# then add to  y:  60
# ...then floor division with 2:  30
# x:  46 y:  30
# iteration:  5
# n floor division y:  22
# then add to  y:  52
# ...then floor division with 2:  26
# x:  30 y:  26
# iteration:  6
# n floor division y:  26
# then add to  y:  52
# ...then floor division with 2:  26
# x:  26 y:  26
# start x:  729 y:  365
# iteration:  1
# n floor division y:  1
# then add to  y:  366
# ...then floor division with 2:  183
# x:  365 y:  183
# iteration:  2
# n floor division y:  3
# then add to  y:  186
# ...then floor division with 2:  93
# x:  183 y:  93
# iteration:  3
# n floor division y:  7
# then add to  y:  100
# ...then floor division with 2:  50
# x:  93 y:  50
# iteration:  4
# n floor division y:  14
# then add to  y:  64
# ...then floor division with 2:  32
# x:  50 y:  32
# iteration:  5
# n floor division y:  22
# then add to  y:  54
# ...then floor division with 2:  27
# x:  32 y:  27
# iteration:  6
# n floor division y:  27
# then add to  y:  54
# ...then floor division with 2:  27
# x:  27 y:  27
# start x:  784 y:  392
# iteration:  1
# n floor division y:  2
# then add to  y:  394
# ...then floor division with 2:  197
# x:  392 y:  197
# iteration:  2
# n floor division y:  3
# then add to  y:  200
# ...then floor division with 2:  100
# x:  197 y:  100
# iteration:  3
# n floor division y:  7
# then add to  y:  107
# ...then floor division with 2:  53
# x:  100 y:  53
# iteration:  4
# n floor division y:  14
# then add to  y:  67
# ...then floor division with 2:  33
# x:  53 y:  33
# iteration:  5
# n floor division y:  23
# then add to  y:  56
# ...then floor division with 2:  28
# x:  33 y:  28
# iteration:  6
# n floor division y:  28
# then add to  y:  56
# ...then floor division with 2:  28
# x:  28 y:  28
# start x:  841 y:  421
# iteration:  1
# n floor division y:  1
# then add to  y:  422
# ...then floor division with 2:  211
# x:  421 y:  211
# iteration:  2
# n floor division y:  3
# then add to  y:  214
# ...then floor division with 2:  107
# x:  211 y:  107
# iteration:  3
# n floor division y:  7
# then add to  y:  114
# ...then floor division with 2:  57
# x:  107 y:  57
# iteration:  4
# n floor division y:  14
# then add to  y:  71
# ...then floor division with 2:  35
# x:  57 y:  35
# iteration:  5
# n floor division y:  24
# then add to  y:  59
# ...then floor division with 2:  29
# x:  35 y:  29
# iteration:  6
# n floor division y:  29
# then add to  y:  58
# ...then floor division with 2:  29
# x:  29 y:  29
# start x:  900 y:  450
# iteration:  1
# n floor division y:  2
# then add to  y:  452
# ...then floor division with 2:  226
# x:  450 y:  226
# iteration:  2
# n floor division y:  3
# then add to  y:  229
# ...then floor division with 2:  114
# x:  226 y:  114
# iteration:  3
# n floor division y:  7
# then add to  y:  121
# ...then floor division with 2:  60
# x:  114 y:  60
# iteration:  4
# n floor division y:  15
# then add to  y:  75
# ...then floor division with 2:  37
# x:  60 y:  37
# iteration:  5
# n floor division y:  24
# then add to  y:  61
# ...then floor division with 2:  30
# x:  37 y:  30
# iteration:  6
# n floor division y:  30
# then add to  y:  60
# ...then floor division with 2:  30
# x:  30 y:  30

# %%
results_table_df = (pd.DataFrame(results_table, columns=["input", "output", "iterations"])
               .assign(approx_cycles=lambda x: x["input"].apply(lambda x: np.log2(x) // 1 ))
                   )

# %%
results_table_df.set_index("input")
# Out:
#        output  iterations  approx_cycles
# input
# 1           1           0            0.0
# 4           2           1            2.0
# 9           3           2            3.0
# 16          4           3            4.0
# 25          5           3            4.0
# 36          6           3            5.0
# 49          7           4            5.0
# 64          8           4            6.0
# 81          9           4            6.0
# 100        10           4            6.0
# 121        11           5            6.0
# 144        12           5            7.0
# 169        13           5            7.0
# 196        14           5            7.0
# 225        15           5            7.0
# 256        16           5            8.0
# 289        17           5            8.0
# 324        18           5            8.0
# 361        19           6            8.0
# 400        20           6            8.0
# 441        21           6            8.0
# 484        22           6            8.0
# 529        23           6            9.0
# 576        24           6            9.0
# 625        25           6            9.0
# 676        26           6            9.0
# 729        27           6            9.0
# 784        28           6            9.0
# 841        29           6            9.0
# 900        30           6            9.0
