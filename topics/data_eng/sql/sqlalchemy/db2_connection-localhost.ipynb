# %%
import sqlalchemy as sa
import pandas as pd
from IPython.core.display import display, HTML, Markdown
display(HTML("<style>.container { width:95% !important; }</style>"))
import json
# Out:
# <style>.container { width:95% !important; }</style>

# %%
! pip install ibm-db-sa
# Out:
# Requirement already satisfied: ibm-db-sa in /Users/james.helfrich/miniconda3/envs/connection/lib/python3.8/site-packages (0.3.5)
# Requirement already satisfied: ibm-db>=2.0.0 in /Users/james.helfrich/miniconda3/envs/connection/lib/python3.8/site-packages (from ibm-db-sa) (3.0.2)
# Requirement already satisfied: sqlalchemy>=0.7.3 in /Users/james.helfrich/miniconda3/envs/connection/lib/python3.8/site-packages (from ibm-db-sa) (1.3.19)

# %%
with open("../creds/creds.json", "r") as f:
    all_creds = json.load(f)

# %%
all_creds.keys()
# Out:
# dict_keys(['mysql', 'ms-sqlserver', 'oracle-db', 'mongo', 'db2', 'ms-sqlserver-openshift'])

# %%
creds = all_creds["db2"]

# %%
creds
# Out:
# {'db': 'BLUDB',
#  'dsn': 'DATABASE=BLUDB;HOSTNAME=dashdb-txn-small-yp-dal13-04.services.dal.bluemix.net;PORT=50000;PROTOCOL=TCPIP;UID=bluadmin;PWD=YjMxZTYyMTBkY2Zh;',
#  'host': 'dashdb-txn-small-yp-dal13-04.services.dal.bluemix.net',
#  'hostname': 'dashdb-txn-small-yp-dal13-04.services.dal.bluemix.net',
#  'https_url': 'https://dashdb-txn-small-yp-dal13-04.services.dal.bluemix.net:8443',
#  'jdbcurl': 'jdbc:db2://dashdb-txn-small-yp-dal13-04.services.dal.bluemix.net:50000/BLUDB',
#  'password': 'YjMxZTYyMTBkY2Zh',
#  'port': 50000,
#  'ssldsn': 'DATABASE=BLUDB;HOSTNAME=dashdb-txn-small-yp-dal13-04.services.dal.bluemix.net;PORT=50001;PROTOCOL=TCPIP;UID=bluadmin;PWD=YjMxZTYyMTBkY2Zh;Security=SSL;',
#  'ssljdbcurl': 'jdbc:db2://dashdb-txn-small-yp-dal13-04.services.dal.bluemix.net:50001/BLUDB:sslConnection=true;',
#  'uri': 'db2://bluadmin:YjMxZTYyMTBkY2Zh@dashdb-txn-small-yp-dal13-04.services.dal.bluemix.net:50000/BLUDB',
#  'username': 'bluadmin'}

# %%
creds = dict(
    host="localhost",
    port="50000",
    username="db2inst1",
    password="password",
    db="GSDB"
)

# %%
locals().update(creds)  # Creating local variables from the JSON entries for this database

# %%
connxn_string = f"db2+ibm_db://{username}:{password}@{host}:{port}/{db}"

# %%
connxn_string
# Out:
# 'db2+ibm_db://bluadmin:YjMxZTYyMTBkY2Zh@dashdb-txn-small-yp-dal13-04.services.dal.bluemix.net:50000/BLUDB'

# %%
engine = sa.create_engine(connxn_string)

# %%
# engine.url

# %%
inspect = sa.inspect(engine)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/ibm_db_dbi.py in connect(dsn, user, password, host, database, conn_options)
#     598     try:
# --> 599         conn = ibm_db.connect(dsn, '', '', conn_options)
#     600         ibm_db.set_option(conn, {SQL_ATTR_CURRENT_SCHEMA : user}, 1)
#
# Exception: [IBM][CLI Driver] SQL30081N  A communication error has been detected. Communication protocol being used: "TCP/IP".  Communication API being used: "SOCKETS".  Location where the error was detected: "169.60.128.187".  Communication function detecting the error: "connect".  Protocol specific error code(s): "61", "*", "*".  SQLSTATE=08001 SQLCODE=-30081
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2337         try:
# -> 2338             return fn()
#    2339         except dialect.dbapi.Error as e:
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     303         """
# --> 304         return _ConnectionFairy._checkout(self)
#     305
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/ibm_db_dbi.py in connect(dsn, user, password, host, database, conn_options)
#     601     except Exception as inst:
# --> 602         raise _get_exception(inst)
#     603
#
# OperationalError: ibm_db_dbi::OperationalError: Exception('[IBM][CLI Driver] SQL30081N  A communication error has been detected. Communication protocol being used: "TCP/IP".  Communication API being used: "SOCKETS".  Location where the error was detected: "169.60.128.187".  Communication function detecting the error: "connect".  Protocol specific error code(s): "61", "*", "*".  SQLSTATE=08001 SQLCODE=-30081')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-53-bef136fa697d> in <module>
# ----> 1 inspect = sa.inspect(engine)
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/inspection.py in inspect(subject, raiseerr)
#      62             if reg is True:
#      63                 return subject
# ---> 64             ret = reg(subject)
#      65             if ret is not None:
#      66                 break
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py in _insp(bind)
#     137     @inspection._inspects(Connectable)
#     138     def _insp(bind):
# --> 139         return Inspector.from_engine(bind)
#     140
#     141     @property
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py in from_engine(cls, bind)
#     133         if hasattr(bind.dialect, "inspector"):
#     134             return bind.dialect.inspector(bind)
# --> 135         return Inspector(bind)
#     136
#     137     @inspection._inspects(Connectable)
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py in __init__(self, bind)
#     106         if self.engine is bind:
#     107             # if engine, ensure initialized
# --> 108             bind.connect().close()
#     109
#     110         self.dialect = self.engine.dialect
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/engine/base.py in connect(self, **kwargs)
#    2263         """
#    2264
# -> 2265         return self._connection_cls(self, **kwargs)
#    2266
#    2267     @util.deprecated(
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     102                 connection
#     103                 if connection is not None
# --> 104                 else engine.raw_connection()
#     105             )
#     106             self.__transaction = None
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    2369
#    2370         """
# -> 2371         return self._wrap_pool_connect(
#    2372             self.pool.unique_connection, _connection
#    2373         )
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2339         except dialect.dbapi.Error as e:
#    2340             if connection is None:
# -> 2341                 Connection._handle_dbapi_exception_noconnection(
#    2342                     e, dialect, self
#    2343                 )
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1581             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1582         elif should_wrap:
# -> 1583             util.raise_(
#    1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2336         dialect = self.dialect
#    2337         try:
# -> 2338             return fn()
#    2339         except dialect.dbapi.Error as e:
#    2340             if connection is None:
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     302
#     303         """
# --> 304         return _ConnectionFairy._checkout(self)
#     305
#     306     def _create_connection(self):
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# ~/miniconda3/envs/connection/lib/python3.8/site-packages/ibm_db_dbi.py in connect(dsn, user, password, host, database, conn_options)
#     600         ibm_db.set_option(conn, {SQL_ATTR_CURRENT_SCHEMA : user}, 1)
#     601     except Exception as inst:
# --> 602         raise _get_exception(inst)
#     603
#     604     return Connection(conn)
#
# OperationalError: (ibm_db_dbi.OperationalError) ibm_db_dbi::OperationalError: Exception('[IBM][CLI Driver] SQL30081N  A communication error has been detected. Communication protocol being used: "TCP/IP".  Communication API being used: "SOCKETS".  Location where the error was detected: "169.60.128.187".  Communication function detecting the error: "connect".  Protocol specific error code(s): "61", "*", "*".  SQLSTATE=08001 SQLCODE=-30081')
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
inspect.get_schema_names()
# Out:
# ['db2inst1',
#  'GOSALES ',
#  'gosalesct',
#  'gosalesdw',
#  'gosaleshr',
#  'gosalesmr',
#  'gosalesrt',
#  'NULLID  ',
#  'SQLJ    ']

# %%
engine.table_names(schema="GOSALES")
# Out:
# ['branch',
#  'conversion_rate',
#  'country',
#  'currency_lookup',
#  'euro_conversion',
#  'inventory_levels',
#  'order_details',
#  'order_header',
#  'order_method',
#  'product',
#  'product_brand',
#  'product_color_lookup',
#  'product_forecast',
#  'product_line',
#  'product_name_lookup',
#  'product_size_lookup',
#  'product_type',
#  'returned_item',
#  'return_reason',
#  'sales_region',
#  'sales_target',
#  'time_dimension',
#  'time_quarter_lookup',
#  'xgorev']

# %%
from sqlalchemy import create_engine, Table, MetaData

# %%
meta = MetaData(schema="GOSALES")

# %%
table = Table('branch', meta, autoload=True, autoload_with=engine, )

# %%
primaryKeyColName = table.primary_key.columns.values()[0].name

# %%
primaryKeyColName
# Out:
# 'branch_code'

# %%
list(table.foreign_keys)[0]
# Out:
# ForeignKey('gosales.country.country_code')

# %% [markdown]
# ## Load csvs

# %%
csvs = """
Auto Insurance Claim.csv
Auto Insurance Policy.csv
Customer Activity.csv
Customer Attrition.csv
Customer Offers.csv
Customer.csv
Mortgage Applicant.csv
Mortgage Customer.csv
Mortgage Default.csv
Mortgage Property.csv
"""

# %%
for file in csvs.strip("\n").split("\n"):
    k = file.strip(".csv").lower().replace(" ", "_")
    df = pd.read_csv(f"../cp4d-mortgage-artifacts/{file}", infer_datetime_format=True)
    
    display(
        Markdown(f"### {k}"),
        df.shape,
        df.head()
    )
    
    df.to_sql(name=k, 
              con=engine, 
              if_exists="replace", 
              schema="mortgage", 
              method="multi",
              index=False
             )
# Out:
# ### auto_insurance_claim
# (1000, 9)
#   CUSTOMER    CLAIM_ID  POLICY_ID FIRST_NOTICE_OF_LOSS_DATE RESPONSE  \
# 0  CH85057  5373215598  PM4788594                2016-08-08       No
# 1  CH85444  8989129787  MT0378990                2016-10-14       No
# 2  CH85444  9636701890  OF0128306                2017-01-02       No
# 3  CH85444  9177470640  SX8636429                2017-03-12       No
# 4  CH97539    16599104  AE6086634                2017-05-31      Yes
#
#    CLAIM_REASON INCIDENT_SUMMARY  CLAIM_AMOUNT  TOTAL_CLAIM_AMOUNT
# 0         Other              NaN   1146.399097          540.141566
# 1     Collision              NaN    414.571186         1067.333126
# 2     Collision              NaN   1067.725385          611.918994
# 3  Scratch/Dent              NaN    807.224559          282.458203
# 4          Hail              NaN    387.364705          701.708239
# ### auto_insurance_policy
# (915, 24)
#   CUSTOMER  POLICY_ID COVERAGE EFFECTIVE_TO_DATE     POLICY_TYPE  \
# 0  CD48033  DG0591347    Basic        2019-02-12   Personal Auto
# 1  CF15086  JF3642903    Basic        2019-01-24  Corporate Auto
# 2  CU13711  KZ6551376    Basic        2019-01-16   Personal Auto
# 3  CU13711  SB4987297    Basic        2019-01-15   Personal Auto
# 4  CU19735  ZN6161626    Basic        2019-01-05  Corporate Auto
#
#          POLICY RENEW_OFFER SALES_CHANNEL  AGENT_ID  FAMILY_MEMBERS_INCLUDED  \
# 0   Personal L1      offer1        Branch         -                        2
# 1  Corporate L2      offer3           Web         -                        2
# 2   Personal L1      offer4           Web         -                        3
# 3   Personal L3      offer2        Branch         -                        1
# 4  Corporate L3      offer2         Agent  Agent-80                        1
#
#    ...  DENIED_CLAIMS  CLAIMS_FILED  AVG_LENGTH_OF_HANDLING_PROCESS  \
# 0  ...              0             0                              14
# 1  ...              0             7                               3
# 2  ...              0             8                              26
# 3  ...              7            15                              23
# 4  ...              5            16                              29
#
#    ADD_DRIVER_INTO_POLICY  ADDRESS_CHANGE_COUNT  MAINTENANCE_COST  \
# 0                       0                     0               7.3
# 1                       0                     0               6.7
# 2                       1                     1               6.9
# 3                       0                     5              18.6
# 4                       0                     3               7.3
#
#    AUTO_MODEL_YEAR  AUTO_MAKE  AUTO_MODEL  AUTO_COLOR
# 0             2017      HONDA      ACCORD       WHITE
# 1             2007     NISSAN      MURANO      SILVER
# 2             2006  CHEVROLET      PICKUP        GRAY
# 3             2012     TOYOTA       PRIUS        GRAY
# 4             2009      HONDA       CIVIC        BLUE
#
# [5 rows x 24 columns]
# ### customer_activity
# (419, 11)
#     ID CUSTOMER  TOTAL_DOLLAR_VALUE_TRADED  TOTAL_UNITS_TRADED  \
# 0  100  BA66627                   15251.53                  70
# 1  101  BA75404                    4580.46                   8
# 2  102  BA92673                    6360.64                  15
# 3  103  BB11622                     570.06                  23
# 4  104  BB82067                    4910.49                   6
#
#    LARGEST_SINGLE_TRANSACTION  SMALLEST_SINGLE_TRANSACTION  \
# 0                   7625.7650                    762.57650
# 1                   1145.1150                    114.51150
# 2                   1590.1600                    159.01600
# 3                    142.5150                     14.25150
# 4                   1227.6225                    122.76225
#
#    PERCENT_CHANGE_CALCULATION  DAYS_SINCE_LAST_LOGIN  DAYS_SINCE_LAST_TRADE  \
# 0                       17.50                      3                      6
# 1                        1.20                      2                     18
# 2                        2.25                      1                     12
# 3                        3.45                      4                     17
# 4                        0.90                      3                     14
#
#    NET_REALIZED_GAINS_YTD  NET_REALIZED_LOSSES_YTD
# 0                762.5765                  0.00000
# 1                  0.0000                229.02300
# 2                  0.0000                159.01600
# 3                  0.0000                 28.50300
# 4                  0.0000                122.76225
# ### customer_attrition
# (419, 2)
#    ID CHURNRISK
# 0   5      High
# 1   6    Medium
# 2   7      High
# 3   8    Medium
# 4   9    Medium
# ### customer_offer
# (419, 7)
#    ID GENDER STATUS  TOTAL_DOLLAR_VALUE_TRADED  TOTAL_UNITS_TRADED  \
# 0   1      F      M                   29782.98                  45
# 1   3      M      S                   26132.61                  32
# 2   8      M      S                    9380.94                  38
# 3  10      F      M                   17441.74                  49
# 4  24      F      S                   21372.14                 293
#
#               OFFER_ACCEPTED  OFFER_COST
# 0              2 Free Trades          10
# 1  5 Free Trades and Consult          50
# 2              5 Free Trades          20
# 3              2 Free Trades          10
# 4              2 Free Trades          10
# ### customer
# (419, 28)
#   CUSTOMER             NAME COUNTRY   LATITUDE   LONGITUDE  \
# 0  AA10041        Rosa Pays      US  37.954863 -121.290404
# 1  AA71604  Janine Cockshot      US  33.599728 -111.988130
# 2  AB13432  Tiphanie Paquet      US  26.180500  -97.720900
# 3  AB21519   Myrvyn Morriss      US  42.010641  -87.829686
# 4  AB31813   Gayler Haburne      US  38.954005  -77.366611
#
#                   STREET_ADDRESS        CITY       STATE STATE_CODE  ZIP_CODE  \
# 0     222 North El Dorado Street    Stockton  California         CA     95202
# 1  12602 N Paradise Village Pkwy     Phoenix     Arizona         AZ     85032
# 2              1002 Dixieland Rd   Harlingen       Texas         TX     78552
# 3            15 S. PROSPECT AVE.  Park Ridge    Illinois         IL     60068
# 4          12197 Sunset Hills Rd      Reston    Virginia         VA     20190
#
#    ...             EDUCATION EMPLOYMENT_STATUS INCOME MARITAL_STATUS  \
# 0  ...              Bachelor          Employed  24964        Married
# 1  ...                Master          Employed  87560        Married
# 2  ...              Bachelor        Unemployed      0         Single
# 3  ...               College          Employed  93272        Married
# 4  ...  High School or Below        Unemployed      0        Married
#
#    CUSTOMER_LIFETIME_VALUE NUMBER_OF_POLICIES NUMBER_OF_CLOSED_COMPLAINTS  \
# 0              9421.101961                  3                           3
# 1              2802.621642                  1                           0
# 2             10628.064150                  3                           0
# 3              2705.987629                  1                           0
# 4              3801.282266                  1                           3
#
#    NUMBER_OF_COMMUNICATIONS NUMBER_OF_COMPLAINTS NUMBER_OF_OPEN_COMPLAINTS
# 0                         8                    4                         0
# 1                         8                    1                         0
# 2                         3                    8                         4
# 3                         2                    2                         1
# 4                         6                    1                         1
#
# [5 rows x 28 columns]
# ### mortgage_applicant
# (419, 14)
#        ID             NAME                 STREET_ADDRESS        CITY  \
# 0  100679    Madelle Augie           1420 Beaumont Avenue    Beaumont
# 1  100537        Rosa Pays     222 North El Dorado Street    Stockton
# 2  100458  Janine Cockshot  12602 N Paradise Village Pkwy     Phoenix
# 3  101432  Tiphanie Paquet              1002 Dixieland Rd   Harlingen
# 4  100599   Myrvyn Morriss            15 S. PROSPECT AVE.  Park Ridge
#
#         STATE STATE_CODE  ZIP_CODE              EMAIL_ADDRESS  PHONE_NUMBER  \
# 0  California         CA     92223           maugie7s@home.pl  603-982-4172
# 1  California         CA     95202      rpaysp8@homestead.com  865-749-5448
# 2     Arizona         AZ     85032  jcockshotqc@wikimedia.org  808-976-1894
# 3       Texas         TX     78552         tpaquet54@gmpg.org  612-256-1393
# 4    Illinois         IL     60068   mmorrissbm@wordpress.com  203-751-1286
#
#    GENDER SOCIAL_SECURITY_NUMBER             EDUCATION EMPLOYMENT_STATUS  \
# 0  Female            886-82-6564  High School or Below        Unemployed
# 1  Female            419-84-5922              Bachelor          Employed
# 2  Female            788-59-0419                Master          Employed
# 3  Female            628-23-7014              Bachelor        Unemployed
# 4    Male            403-49-3264               College          Employed
#
#   MARITAL_STATUS
# 0         Single
# 1        Married
# 2        Married
# 3         Single
# 4        Married
# ### mortgage_customer
# (419, 10)
#        ID  INCOME APPLIEDONLINE       RESIDENCE  YRS_AT_CURRENT_ADDRESS  \
# 0  100537   45081           YES  Owner Occupier                      14
# 1  100458   46645           YES  Owner Occupier                      19
# 2  101432   44202           YES  Owner Occupier                       1
# 3  100599   52495           YES  Owner Occupier                      18
# 4  100782   43608           YES  Owner Occupier                       2
#
#    YRS_WITH_CURRENT_EMPLOYER  NUMBER_OF_CARDS  CREDITCARD_DEBT  LOANS  \
# 0                         15                2              713      1
# 1                          4                1              884      0
# 2                         23                2             2611      0
# 3                         16                2             2527      1
# 4                         20                1              452      0
#
#    LOAN_AMOUNT
# 0         8430
# 1         6045
# 2        12915
# 3        10375
# 4         7610
# ### mortgage_default
# (419, 2)
#        ID MORTGAGE_DEFAULT
# 0  101600              YES
# 1  101731               NO
# 2  100548              YES
# 3  101472               NO
# 4  100562              YES
# ### mortgage_property
# (419, 3)
#        ID  SALEPRICE LOCATION
# 0  101472     340000     L100
# 1  100624     190000     L100
# 2  100532     190000     L100
# 3  100403     161000     L100
# 4  100477     192500     L100

# %% [markdown]
# ## Check to make sure it worked

# %%
for file in csvs.strip("\n").split("\n"):
    k = file.strip(".csv").lower().replace(" ", "_")
    display(Markdown(f"### {k}"))
    df = pd.read_sql_table(k, con=engine, schema="mortgage")
    print(df.shape)
    display(df.head())
# Out:
# ### auto_insurance_claim
# (1000, 9)
#   customer    claim_id  policy_id first_notice_of_loss_date response  \
# 0  CH85057  5373215598  PM4788594                2016-08-08       No
# 1  CH85444  8989129787  MT0378990                2016-10-14       No
# 2  CH85444  9636701890  OF0128306                2017-01-02       No
# 3  CH85444  9177470640  SX8636429                2017-03-12       No
# 4  CH97539    16599104  AE6086634                2017-05-31      Yes
#
#    claim_reason incident_summary  claim_amount  total_claim_amount
# 0         Other             None   1146.399097          540.141566
# 1     Collision             None    414.571186         1067.333126
# 2     Collision             None   1067.725385          611.918994
# 3  Scratch/Dent             None    807.224559          282.458203
# 4          Hail             None    387.364705          701.708239
# ### auto_insurance_policy
# (915, 24)
#   customer  policy_id coverage effective_to_date     policy_type  \
# 0  CD48033  DG0591347    Basic        2019-02-12   Personal Auto
# 1  CF15086  JF3642903    Basic        2019-01-24  Corporate Auto
# 2  CU13711  KZ6551376    Basic        2019-01-16   Personal Auto
# 3  CU13711  SB4987297    Basic        2019-01-15   Personal Auto
# 4  CU19735  ZN6161626    Basic        2019-01-05  Corporate Auto
#
#          policy renew_offer sales_channel  agent_id  family_members_included  \
# 0   Personal L1      offer1        Branch         -                        2
# 1  Corporate L2      offer3           Web         -                        2
# 2   Personal L1      offer4           Web         -                        3
# 3   Personal L3      offer2        Branch         -                        1
# 4  Corporate L3      offer2         Agent  Agent-80                        1
#
#    ...  denied_claims  claims_filed  avg_length_of_handling_process  \
# 0  ...              0             0                              14
# 1  ...              0             7                               3
# 2  ...              0             8                              26
# 3  ...              7            15                              23
# 4  ...              5            16                              29
#
#    add_driver_into_policy  address_change_count  maintenance_cost  \
# 0                       0                     0               7.3
# 1                       0                     0               6.7
# 2                       1                     1               6.9
# 3                       0                     5              18.6
# 4                       0                     3               7.3
#
#    auto_model_year  auto_make  auto_model  auto_color
# 0             2017      HONDA      ACCORD       WHITE
# 1             2007     NISSAN      MURANO      SILVER
# 2             2006  CHEVROLET      PICKUP        GRAY
# 3             2012     TOYOTA       PRIUS        GRAY
# 4             2009      HONDA       CIVIC        BLUE
#
# [5 rows x 24 columns]
# ### customer_activity
# (419, 11)
#     id customer  total_dollar_value_traded  total_units_traded  \
# 0  100  BA66627                   15251.53                  70
# 1  101  BA75404                    4580.46                   8
# 2  102  BA92673                    6360.64                  15
# 3  103  BB11622                     570.06                  23
# 4  104  BB82067                    4910.49                   6
#
#    largest_single_transaction  smallest_single_transaction  \
# 0                   7625.7650                    762.57650
# 1                   1145.1150                    114.51150
# 2                   1590.1600                    159.01600
# 3                    142.5150                     14.25150
# 4                   1227.6225                    122.76225
#
#    percent_change_calculation  days_since_last_login  days_since_last_trade  \
# 0                       17.50                      3                      6
# 1                        1.20                      2                     18
# 2                        2.25                      1                     12
# 3                        3.45                      4                     17
# 4                        0.90                      3                     14
#
#    net_realized_gains_ytd  net_realized_losses_ytd
# 0                762.5765                  0.00000
# 1                  0.0000                229.02300
# 2                  0.0000                159.01600
# 3                  0.0000                 28.50300
# 4                  0.0000                122.76225
# ### customer_attrition
# (419, 2)
#    id churnrisk
# 0   5      High
# 1   6    Medium
# 2   7      High
# 3   8    Medium
# 4   9    Medium
# ### customer_offer
# (419, 7)
#    id gender status  total_dollar_value_traded  total_units_traded  \
# 0   1      F      M                   29782.98                  45
# 1   3      M      S                   26132.61                  32
# 2   8      M      S                    9380.94                  38
# 3  10      F      M                   17441.74                  49
# 4  24      F      S                   21372.14                 293
#
#               offer_accepted  offer_cost
# 0              2 Free Trades          10
# 1  5 Free Trades and Consult          50
# 2              5 Free Trades          20
# 3              2 Free Trades          10
# 4              2 Free Trades          10
# ### customer
# (419, 28)
#   customer             name country   latitude   longitude  \
# 0  AA10041        Rosa Pays      US  37.954863 -121.290404
# 1  AA71604  Janine Cockshot      US  33.599728 -111.988130
# 2  AB13432  Tiphanie Paquet      US  26.180500  -97.720900
# 3  AB21519   Myrvyn Morriss      US  42.010641  -87.829686
# 4  AB31813   Gayler Haburne      US  38.954005  -77.366611
#
#                   street_address        city       state state_code  zip_code  \
# 0     222 North El Dorado Street    Stockton  California         CA     95202
# 1  12602 N Paradise Village Pkwy     Phoenix     Arizona         AZ     85032
# 2              1002 Dixieland Rd   Harlingen       Texas         TX     78552
# 3            15 S. PROSPECT AVE.  Park Ridge    Illinois         IL     60068
# 4          12197 Sunset Hills Rd      Reston    Virginia         VA     20190
#
#    ...             education employment_status income marital_status  \
# 0  ...              Bachelor          Employed  24964        Married
# 1  ...                Master          Employed  87560        Married
# 2  ...              Bachelor        Unemployed      0         Single
# 3  ...               College          Employed  93272        Married
# 4  ...  High School or Below        Unemployed      0        Married
#
#    customer_lifetime_value number_of_policies number_of_closed_complaints  \
# 0              9421.101961                  3                           3
# 1              2802.621642                  1                           0
# 2             10628.064150                  3                           0
# 3              2705.987629                  1                           0
# 4              3801.282266                  1                           3
#
#    number_of_communications number_of_complaints number_of_open_complaints
# 0                         8                    4                         0
# 1                         8                    1                         0
# 2                         3                    8                         4
# 3                         2                    2                         1
# 4                         6                    1                         1
#
# [5 rows x 28 columns]
# ### mortgage_applicant
# (419, 14)
#        id             name                 street_address        city  \
# 0  100679    Madelle Augie           1420 Beaumont Avenue    Beaumont
# 1  100537        Rosa Pays     222 North El Dorado Street    Stockton
# 2  100458  Janine Cockshot  12602 N Paradise Village Pkwy     Phoenix
# 3  101432  Tiphanie Paquet              1002 Dixieland Rd   Harlingen
# 4  100599   Myrvyn Morriss            15 S. PROSPECT AVE.  Park Ridge
#
#         state state_code  zip_code              email_address  phone_number  \
# 0  California         CA     92223           maugie7s@home.pl  603-982-4172
# 1  California         CA     95202      rpaysp8@homestead.com  865-749-5448
# 2     Arizona         AZ     85032  jcockshotqc@wikimedia.org  808-976-1894
# 3       Texas         TX     78552         tpaquet54@gmpg.org  612-256-1393
# 4    Illinois         IL     60068   mmorrissbm@wordpress.com  203-751-1286
#
#    gender social_security_number             education employment_status  \
# 0  Female            886-82-6564  High School or Below        Unemployed
# 1  Female            419-84-5922              Bachelor          Employed
# 2  Female            788-59-0419                Master          Employed
# 3  Female            628-23-7014              Bachelor        Unemployed
# 4    Male            403-49-3264               College          Employed
#
#   marital_status
# 0         Single
# 1        Married
# 2        Married
# 3         Single
# 4        Married
# ### mortgage_customer
# (419, 10)
#        id  income appliedonline       residence  yrs_at_current_address  \
# 0  100537   45081           YES  Owner Occupier                      14
# 1  100458   46645           YES  Owner Occupier                      19
# 2  101432   44202           YES  Owner Occupier                       1
# 3  100599   52495           YES  Owner Occupier                      18
# 4  100782   43608           YES  Owner Occupier                       2
#
#    yrs_with_current_employer  number_of_cards  creditcard_debt  loans  \
# 0                         15                2              713      1
# 1                          4                1              884      0
# 2                         23                2             2611      0
# 3                         16                2             2527      1
# 4                         20                1              452      0
#
#    loan_amount
# 0         8430
# 1         6045
# 2        12915
# 3        10375
# 4         7610
# ### mortgage_default
# (419, 2)
#        id mortgage_default
# 0  101600              YES
# 1  101731               NO
# 2  100548              YES
# 3  101472               NO
# 4  100562              YES
# ### mortgage_property
# (419, 3)
#        id  saleprice location
# 0  101472     340000     L100
# 1  100624     190000     L100
# 2  100532     190000     L100
# 3  100403     161000     L100
# 4  100477     192500     L100
